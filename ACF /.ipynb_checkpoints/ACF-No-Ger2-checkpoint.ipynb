# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
plt.style.use('seaborn-whitegrid')
pd.set_option("display.precision", 5)

# %%
# magic to reload modules automatically
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ff = pd.read_excel('data/5factors.xlsx')
rt = pd.read_excel('data/north.xlsx' , skiprows=3)
esg = pd.read_excel('data/north31.xlsx', skiprows=3)
print(rt.shape)
print(esg.shape)
print(ff.shape)
# Out:
# (2352, 124)
# (12, 739)
# (8261, 7)

# %%
pd.set_option('display.max_columns',735) # I want to see all the columns
pd.set_option('display.max_rows',735)

# %%
ff.rename(columns = {'Unnamed: 0' : 'date'}, inplace=True)
ff['date'] = pd.to_datetime(ff['date'], format='%Y%m%d')
filt = (ff['date'] >= pd.to_datetime('2013-04-03')) & (ff['date'] <= pd.to_datetime('2022-02-28'))
ff = ff[filt]
ff.reset_index(inplace = True, drop = True)

# %%
rt.drop(index=[0,1,2], inplace=True)
rt.reset_index(inplace = True, drop = True) # Drop old index too

# %%
it = rt.copy()
it.to_excel('it.xlsx')

# %%
rt.rename(columns={'Unnamed: 0':'date'},inplace = True) 
xx = ['1COV GY Equity','DTG GY Equity','SINCH SS Equity',
                 'SHL GY Equity','NEL NO Equity','DHER GY Equity',
                 'HFG GY Equity','LIN GY Equity','NETS DC Equity',
                 'DAX Index','OMXS30B Index','OMXC25 Index','OMX Index']
drop_these = []
for i in xx:
    for j in range(1,6):
        drop_these.append(i + '.' + str(j))
drop_these = xx + drop_these
rt.drop(columns=xx, inplace = True)

# %%
rt.columns = rt.columns.str.replace(' GY', ' G')
rt.columns = rt.columns.str.replace(' SS', ' S')
rt.columns = rt.columns.str.replace(' NO', ' N')
rt.columns = rt.columns.str.replace(' DC', ' D')
rt.columns = rt.columns.str.replace(' Equity', '')
rt.columns = rt.columns.str.replace(' ', '_')

# %%
rt['date'] = pd.to_datetime(rt['date'])
#rt.set_index('date',inplace = True)

# %%
esg.drop(columns=drop_these,inplace = True) 
esg.drop(index=[0,2], inplace=True)
esg.rename(columns={'Unnamed: 0':'Date'},inplace = True) 
esg.reset_index(inplace = True, drop = True)

# %%
esg.replace({'ESG_DISCLOSURE_SCORE': 'ESG', 'ENVIRON_DISCLOSURE_SCORE': 'E',
             'SOCIAL_DISCLOSURE_SCORE': 'S','GOVNCE_DISCLOSURE_SCORE': 'G',
             'HISTORICAL_MARKET_CAP' : 'HMCAP', 'CUR_MKT_CAP': 'MCAP'}, inplace=True)

# %%
asg = esg.iloc[1] + ' ' + esg.iloc[0]
esg = esg.append(asg, ignore_index=True)
esg.loc[10,'Date'] = 'date'
nnn = esg.loc[10]
esg.rename(columns=nnn, inplace=True)
esg.drop(index=[0,1,10], inplace=True)
esg.reset_index(inplace = True, drop = True)

# %%
esg.columns = esg.columns.str.replace(' GY', ' G')
esg.columns = esg.columns.str.replace(' SS', ' S')
esg.columns = esg.columns.str.replace(' NO', ' N')
esg.columns = esg.columns.str.replace(' DC', ' D')
esg.columns = esg.columns.str.replace(' Equity', '')
esg.columns = esg.columns.str.replace(' ', '_')
esg.set_index('date', inplace=True)

# %%
esg_esg = esg.loc[:,'ADS_G_ESG':'VWS_D_ESG']
esg_esg.columns = esg_esg.columns.str.replace('_ESG', '')

# %%
for i in rt.columns[1:]:
    rt.loc[:,i] = rt.loc[:,i].pct_change(1)*100
rt.drop(index=[0], inplace=True)

# %%
nyind = []
for i in esg_esg.index:
    nyind.append(str(i)+ '_esg')
esg_esg.index = nyind

# %%
rtt = pd.concat([rt, esg_esg])

# %%
#rtt.drop(columns='EVO_S', inplace=True)
#rt.drop(columns='EVO_S', inplace=True)
#no_ger = rtt.columns[1:35].tolist()
#rtt.drop(columns=no_ger, inplace=True)
#rt.drop(columns=no_ger, inplace=True)

# %%
filt = (rtt['date'] >= pd.to_datetime('2013-01-01')) & (rtt['date'] <= pd.to_datetime('2013-12-31')) 
thirteen = rtt[filt]
thirteen = pd.concat([thirteen, esg_esg])
thirteen = thirteen.replace(0, np.nan)
thirteen.dropna(how='all', axis='columns', thresh=150, inplace=True)
thirteen = thirteen.replace(np.nan, 0)
nah = ['2015_esg','2016_esg','2017_esg','2018_esg','2019_esg','2020_esg','2021_esg']
thirteen.drop(index=nah, inplace=True)
print(thirteen.shape)
# Out:
# (196, 103)

# %%
#  2013
q_l = thirteen.loc[thirteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(0.33)
q_h = thirteen.loc[thirteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(0.67)
I = (thirteen.loc['2014_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (thirteen.loc['2014_esg', 'ADS_G':'VWS_D'] > q_l) & (thirteen.loc['2014_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (thirteen.loc['2014_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
thirteen = thirteen.sort_values(by = '2014_esg', axis = 1, na_position ='first')
thirteen_low = I[I==True].index.tolist()
thirteen_mid = Ii[Ii==True].index.tolist()
thirteen_high = Iii[Iii==True].index.tolist()

# %%
#2013
# low
thirteen = thirteen.iloc[:-1]
low_p=[]
for i in range(len(thirteen)):
     low_p.append(thirteen.iloc[i, 1:I_sum].mean())

# mid
mid_p=[]
for i in range(len(thirteen)):
     mid_p.append(thirteen.iloc[i, I_sum:Ii_sum].mean())

# high
high_p=[]
for i in range(len(thirteen)):
     high_p.append(thirteen.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
filt = (rtt['date'] >= pd.to_datetime('2014-01-01')) & (rtt['date'] <= pd.to_datetime('2014-12-31')) 
fourteen = rtt[filt]
fourteen = pd.concat([fourteen, esg_esg])
fourteen = fourteen.replace(0, np.nan)
fourteen.dropna(how='all', axis='columns', thresh=100, inplace=True)
fourteen = fourteen.replace(np.nan, 0)
nah = ['2015_esg','2016_esg','2017_esg','2018_esg','2019_esg','2020_esg','2021_esg']
fourteen.drop(index=nah, inplace=True)
fourteen.sort_values(by = '2014_esg', axis = 1, na_position ='first', inplace=True)

# %%
#2014
# low
fourteen = fourteen.iloc[:-1]
for i in range(len(fourteen)):
     low_p.append(fourteen.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(fourteen)):
     mid_p.append(fourteen.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(fourteen)):
     high_p.append(fourteen.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2015
filt = (rtt['date'] >= pd.to_datetime('2015-01-01')) & (rtt['date'] <= pd.to_datetime('2015-12-31')) 
fifteen = rtt[filt]
fifteen = pd.concat([fifteen, esg_esg])
fifteen = fifteen.replace(0, np.nan)
fifteen.dropna(how='all', axis='columns', thresh=100, inplace=True)
fifteen = fifteen.replace(np.nan, 0)
nah = ['2014_esg','2016_esg','2017_esg','2018_esg','2019_esg','2020_esg','2021_esg']
fifteen.drop(index=nah, inplace=True)

q_l = fifteen.loc[fifteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(0.33)
q_h = fifteen.loc[fifteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(0.67)
I = (fifteen.loc['2015_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (fifteen.loc['2015_esg', 'ADS_G':'VWS_D'] > q_l) & (fifteen.loc['2015_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (fifteen.loc['2015_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
fifteen_low = I[I==True].index.tolist()
fifteen_mid = Ii[Ii==True].index.tolist()
fifteen_high = Iii[Iii==True].index.tolist()

# %%
print(fifteen.shape)
Iii.sum()
# Out:
# (262, 109)
# 36

# %%
fifteen.sort_values(by = '2015_esg', axis = 1, na_position ='first', inplace=True)

# %%
#2015
# low
fifteen = fifteen.iloc[:-1]
for i in range(len(fifteen)):
     low_p.append(fifteen.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(fifteen)):
     mid_p.append(fifteen.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(fifteen)):
     high_p.append(fifteen.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2016
filt = (rtt['date'] >= pd.to_datetime('2016-01-01')) & (rtt['date'] <= pd.to_datetime('2016-12-31')) 
sixteen = rtt[filt]
sixteen = pd.concat([sixteen, esg_esg])
sixteen = sixteen.replace(0, np.nan)
sixteen.dropna(how='all', axis='columns', thresh=120, inplace=True)
sixteen = sixteen.replace(np.nan, 0)
nah = ['2014_esg','2015_esg','2017_esg','2018_esg','2019_esg','2020_esg','2021_esg']
sixteen.drop(index=nah, inplace=True)

q_l = sixteen.loc[sixteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.33)
q_h = sixteen.loc[sixteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.67)
I = (sixteen.loc['2016_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (sixteen.loc['2016_esg', 'ADS_G':'VWS_D'] > q_l) & (sixteen.loc['2016_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (sixteen.loc['2016_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
sixteen_low = I[I==True].index.tolist()
sixteen_mid = Ii[Ii==True].index.tolist()
sixteen_high = Iii[Iii==True].index.tolist()
print(sixteen.shape)
print(I_sum)
print(Ii_sum)
print(Iii_sum)
# Out:
# (262, 110)
# 36
# 73
# 109

# %%
print(sixteen.shape)
# Out:
# (262, 110)

# %%
sixteen.sort_values(by = '2016_esg', axis = 1, na_position ='first', inplace=True)

# %%
#  2016
# low
sixteen = sixteen.iloc[:-1]
for i in range(len(sixteen)):
     low_p.append(sixteen.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(sixteen)):
     mid_p.append(sixteen.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(sixteen)):
     high_p.append(sixteen.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2017
filt = (rtt['date'] >= pd.to_datetime('2017-01-01')) & (rtt['date'] <= pd.to_datetime('2017-12-31')) 
seventeen = rtt[filt]
seventeen = pd.concat([seventeen, esg_esg])
seventeen = seventeen.replace(0, np.nan)
seventeen.dropna(how='all', axis='columns', thresh=120, inplace=True)
seventeen = seventeen.replace(np.nan, 0)
nah = ['2014_esg','2015_esg','2016_esg','2018_esg','2019_esg','2020_esg','2021_esg']
seventeen.drop(index=nah, inplace=True)

q_l = seventeen.loc[seventeen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.333)
q_h = seventeen.loc[seventeen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.67)
I = (seventeen.loc['2017_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (seventeen.loc['2017_esg', 'ADS_G':'VWS_D'] > q_l) & (seventeen.loc['2017_esg', 'ADS_G':'VWS_D'] < q_h)
Iii = (seventeen.loc['2017_esg', 'ADS_G':'VWS_D'] >= q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
seventeen_low = I[I==True].index.tolist()
seventeen_mid = Ii[Ii==True].index.tolist()
seventeen_high = Iii[Iii==True].index.tolist()
print(seventeen.shape)
print(I_sum)
print(Ii_sum)
print(Iii_sum)
# Out:
# (261, 111)
# 37
# 74
# 110

# %%
seventeen.sort_values(by = '2017_esg', axis = 1, na_position ='first', inplace=True)

# %%
#  2017
# low
seventeen = seventeen.iloc[:-1]
for i in range(len(seventeen)):
     low_p.append(seventeen.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(seventeen)):
     mid_p.append(seventeen.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(seventeen)):
     high_p.append(seventeen.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2018
filt = (rtt['date'] >= pd.to_datetime('2018-01-01')) & (rtt['date'] <= pd.to_datetime('2018-12-31')) 
eighteen  = rtt[filt]
eighteen = pd.concat([eighteen, esg_esg])
eighteen = eighteen.replace(0, np.nan)
eighteen.dropna(how='all', axis='columns', thresh=120, inplace=True)
eighteen = eighteen.replace(np.nan, 0)
nah = ['2014_esg','2015_esg','2016_esg','2017_esg','2019_esg','2020_esg','2021_esg']
eighteen.drop(index=nah, inplace=True)

q_l = eighteen.loc[eighteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.333)
q_h = eighteen.loc[eighteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.67)
I = (eighteen.loc['2018_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (eighteen.loc['2018_esg', 'ADS_G':'VWS_D'] > q_l) & (eighteen.loc['2018_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (eighteen.loc['2018_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
eighteen_low = I[I==True].index.tolist()
eighteen_mid = Ii[Ii==True].index.tolist()
eighteen_high = Iii[Iii==True].index.tolist()

# %%
eighteen.sort_values(by = '2018_esg', axis = 1, na_position ='first', inplace=True)

# %%
#  2018
# low
eighteen = eighteen.iloc[:-1]
for i in range(len(eighteen)):
     low_p.append(eighteen.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(eighteen)):
     mid_p.append(eighteen.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(eighteen)):
     high_p.append(eighteen.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2019
filt = (rtt['date'] >= pd.to_datetime('2019-01-01')) & (rtt['date'] <= pd.to_datetime('2019-12-31')) 
nineteen  = rtt[filt]
nineteen = pd.concat([nineteen, esg_esg])
nineteen = nineteen.replace(0, np.nan)
nineteen = nineteen.replace(np.nan, 0)
nah = ['2014_esg','2015_esg','2016_esg','2017_esg','2018_esg','2020_esg','2021_esg']
nineteen.drop(index=nah, inplace=True)

q_l = nineteen.loc[nineteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.333)
q_h = nineteen.loc[nineteen.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.67)
I = (nineteen.loc['2019_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (nineteen.loc['2019_esg', 'ADS_G':'VWS_D'] > q_l) & (nineteen.loc['2019_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (nineteen.loc['2019_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
nineteen_low = I[I==True].index.tolist()
nineteen_mid = Ii[Ii==True].index.tolist()
nineteen_high = Iii[Iii==True].index.tolist()

# %%
nineteen.sort_values(by = '2019_esg', axis = 1, na_position ='first', inplace=True)

# %%
#  2019
# low
nineteen = nineteen.iloc[:-1]
for i in range(len(nineteen)):
     low_p.append(nineteen.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(nineteen)):
     mid_p.append(nineteen.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(nineteen)):
     high_p.append(nineteen.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2020
filt = (rtt['date'] >= pd.to_datetime('2020-01-01')) & (rtt['date'] <= pd.to_datetime('2020-12-31')) 
twenty   = rtt[filt]
twenty = pd.concat([twenty, esg_esg])
twenty = twenty.replace(0, np.nan)
twenty = twenty.replace(np.nan, 0)
nah = ['2014_esg','2015_esg','2016_esg','2017_esg','2018_esg','2019_esg','2021_esg']
twenty.drop(index=nah, inplace=True)

q_l = twenty.loc[twenty.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.333)
q_h = twenty.loc[twenty.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.67)
I = (twenty.loc['2020_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (twenty.loc['2020_esg', 'ADS_G':'VWS_D'] > q_l) & (twenty.loc['2020_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (twenty.loc['2020_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
twenty_low = I[I==True].index.tolist()
twenty_mid = Ii[Ii==True].index.tolist()
twenty_high = Iii[Iii==True].index.tolist()

# %%
twenty.sort_values(by = '2020_esg', axis = 1, na_position ='first', inplace=True)

# %%
#  2020
# low
twenty = twenty.iloc[:-1]
for i in range(len(twenty)):
     low_p.append(twenty.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(twenty)):
     mid_p.append(twenty.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(twenty)):
     high_p.append(twenty.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2021
filt = (rtt['date'] >= pd.to_datetime('2021-01-01')) & (rtt['date'] <= pd.to_datetime('2021-12-31')) 
twentyone = rtt[filt]
twentyone = pd.concat([twentyone, esg_esg])
twentyone = twentyone.replace(0, np.nan)
twentyone = twentyone.replace(np.nan, 0)
nah = ['2014_esg','2015_esg','2016_esg','2017_esg','2018_esg','2019_esg','2020_esg']
twentyone.drop(index=nah, inplace=True)

q_l = twentyone.loc[twentyone.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.333)
q_h = twentyone.loc[twentyone.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.67)
I = (twentyone.loc['2021_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (twentyone.loc['2021_esg', 'ADS_G':'VWS_D'] > q_l) & (twentyone.loc['2021_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (twentyone.loc['2021_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
twentyone_low = I[I==True].index.tolist()
twentyone_mid = Ii[Ii==True].index.tolist()
twentyone_high = Iii[Iii==True].index.tolist()

# %%
twentyone.sort_values(by = '2021_esg', axis = 1, na_position ='first', inplace=True)

# %%
#  2021
# low
twentyone = twentyone.iloc[:-1]
for i in range(len(twentyone)):
     low_p.append(twentyone.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(twentyone)):
     mid_p.append(twentyone.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(twentyone)):
     high_p.append(twentyone.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
#  2022
filt = (rtt['date'] >= pd.to_datetime('2022-01-01')) & (rtt['date'] <= pd.to_datetime('2022-04-02')) 
twentytwo = rtt[filt]
twentytwo = pd.concat([twentytwo, esg_esg])
twentytwo = twentytwo.replace(0, np.nan)
twentytwo = twentytwo.replace(np.nan, 0)
nah = ['2014_esg','2015_esg','2016_esg','2017_esg','2018_esg','2019_esg','2020_esg']
twentytwo.drop(index=nah, inplace=True)

q_l = twentytwo.loc[twentytwo.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.333)
q_h = twentytwo.loc[twentytwo.index[-1], 'ADS_G' : 'VWS_D'].quantile(q=0.67)
I = (twentytwo.loc['2021_esg', 'ADS_G':'VWS_D'] <= q_l)
Ii = (twentytwo.loc['2021_esg', 'ADS_G':'VWS_D'] > q_l) & (twentytwo.loc['2021_esg', 'ADS_G':'VWS_D'] <= q_h)
Iii = (twentytwo.loc['2021_esg', 'ADS_G':'VWS_D'] > q_h)
I_sum = I.sum()
Ii_sum = Ii.sum() + I_sum
Iii_sum = Iii.sum() + Ii_sum
twentytwo_low = I[I==True].index.tolist()
twentytwo_mid = Ii[Ii==True].index.tolist()
twentytwo_high = Iii[Iii==True].index.tolist()

# %%
twentytwo.sort_values(by = '2021_esg', axis = 1, na_position ='first', inplace=True)

# %%
#  2022
# low
twentytwo = twentytwo.iloc[:-1]
for i in range(len(twentytwo)):
     low_p.append(twentytwo.iloc[i, 1:I_sum].mean())

# mid
for i in range(len(twentytwo)):
     mid_p.append(twentytwo.iloc[i, I_sum:Ii_sum].mean())

# high
for i in range(len(twentytwo)):
     high_p.append(twentytwo.iloc[i, Ii_sum:Iii_sum + 1].mean())

# %%
plt.plot(low_p, label = 'low')
plt.plot(mid_p, label = 'mid')
plt.plot(high_p, label = 'high')
plt.legend();

# %%
rt['port_low'] = low_p
rt['port_mid'] = mid_p
rt['port_high'] = high_p

# %%
rt.to_excel('rt.xlsx')
ff.to_excel('ff.xlsx')
esg_esg.to_excel('esg_esg.xlsx')

# %%
test = rt.copy()
test = test.replace(0, np.nan)
test.dropna(how='all', axis='index', thresh=4, inplace=True)
test = test.replace(np.nan, 0)
tab = test.describe()

# %%
plt.plot(tab.loc['mean',:]);

# %%
high_r = tab.loc['mean',:].sort_values(ascending=False).tolist()
tab.loc['mean',:].sort_values(ascending=False).head()
# Out:
# EVO_S      0.21323
# VWS_D      0.17069
# SRT3_G     0.15236
# GMAB_D     0.15066
# AMBUB_D    0.14433
# Name: mean, dtype: float64

# %%
esg_high_r = esg_esg.loc[:,['EVO_S','VWS_D','SRT3_G','GMAB_D','AMBUB_D','SALM_N','BAKKA_N','DSV_D','TOM_N','BAVA_D' ]].mean().tolist()

# %%
plt.scatter(esg_high_r,high_r[:10]);

# %%
high_l = tab.loc['mean',:].sort_values(ascending=True).tolist()
high_l=high_l[:10]
high_l
# Out:
# [-0.007577846288507962,
#  -0.0064064096904672555,
#  -0.005931230426752646,
#  -0.0010747911778650062,
#  -0.0003733766893817676,
#  0.0010157417762705102,
#  0.0017071686303182874,
#  0.004610171886979687,
#  0.004888015296645593,
#  0.006963521387807491]

# %%
esg_high_l = esg_esg.loc[:,['HMB_S','FLS_D','DBK_G','TELIA_S','HEN3_G','BAS_G','ESSITYB_S','BAYN_G','ISS_D','EOAN_G' ]].mean().tolist()
esg_high_l
# Out:
# [43.33820000000001,
#  45.759975000000004,
#  45.59904999999999,
#  47.585762499999994,
#  51.610749999999996,
#  62.9300375,
#  60.69344999999999,
#  67.94212499999999,
#  49.638912499999996,
#  60.41645]

# %%
plt.scatter(esg_high_l,high_l);

# %%
esg
# Out:
#      ADS_G_ESG AIR_G_ESG ALV_G_ESG BAS_G_ESG BAYN_G_ESG BMW_G_ESG BNR_G_ESG  \
# date
# 2014   51.9968   50.8264   52.1879   58.2336    60.6881   57.3282   30.1653
# 2015   52.7009   47.5207   53.5761   59.9638    60.9697   67.5184   33.8843
# 2016    48.134    46.281   53.4654     61.01    68.1018   68.9166   35.3687
# 2017   50.9607   49.1736   53.1435   63.3437    66.3012   65.3254   43.3759
# 2018   51.2826   51.2397   56.1714   64.3698    67.1663   69.5202   43.5067
# 2019   51.2826   48.3471   57.5797    64.239    72.2161   73.6948    44.241
# 2020   51.7755   55.4874   58.0324   66.1402    74.0469   73.9262   44.0097
# 2021   51.7755   55.4874   58.0324   66.1402    74.0469   73.9262   44.0097
#
#      CON_G_ESG DB1_G_ESG DBK_G_ESG DPW_G_ESG DTE_G_ESG EOAN_G_ESG FME_G_ESG  \
# date
# 2014    29.494   58.7768   35.9924   43.1647    30.671    43.1948   25.8626
# 2015    47.973   52.0169   42.2292   52.1477   39.8551    55.0347   22.3116
# 2016   51.8157   55.5779   42.5712   52.1477   44.7239    56.4631   26.6573
# 2017   57.7708   56.5235   48.8381   52.6708   44.8647    60.5875    33.216
# 2018   46.6653   56.2418   49.2808   54.7329   51.2725     64.239   42.4002
# 2019   49.5624   55.5779   48.6269   53.7169   51.2725    66.1603   42.9232
# 2020   53.0933   50.1358   48.6269   53.9382   55.4773    68.8261   43.1546
# 2021   53.0933   46.9872   48.6269   53.9382   55.4773    68.8261   43.1546
#
#      FRE_G_ESG HEI_G_ESG HEN3_G_ESG HNR1_G_ESG IFX_G_ESG MBG_G_ESG MRK_G_ESG  \
# date
# 2014   14.8174   43.5469    41.2635    29.6047   47.9339   49.0494    43.557
# 2015   16.5275   43.9895     43.728     33.387   51.1015   55.3164   51.9264
# 2016   21.5069    45.931    49.7938    34.0207   51.1015   55.3164   56.3324
# 2017   36.9078   52.2181    50.7192    45.3576   62.1366   55.4069   55.6886
# 2018   38.5575   52.2181    56.6844    45.3576   62.8005   55.4069   57.3584
# 2019   41.9173   54.7631    56.0507     45.086   63.1425   58.2235   58.8774
# 2020   43.7481   55.9099    56.3927    44.1304   63.1425   69.6509   63.1425
# 2021   43.7481   55.9099    58.2537    44.1304   62.0964   69.6509   63.1425
#
#      MTX_G_ESG MUV2_G_ESG PAH3_G_ESG PUM_G_ESG QIA_G_ESG RWE_G_ESG SAP_G_ESG  \
# date
# 2014   51.2397    48.7074     15.934   34.5337   27.9248   38.8894   37.2095
# 2015    53.719    45.1061    20.6518   39.5534   28.1159   46.2931   47.1985
#       NOVOB_D_MCAP NZYMB_D_MCAP ORSTED_D_MCAP PNDORA_D_MCAP ROCKB_D_MCAP  \
# date
# 2014   689794.9841   83058.0572           NaN    64634.4283    15193.706
# 2015  1039739.9756  103477.8025           NaN   106643.1345   21063.4522
# 2016   649484.9845   75485.0019   112493.9751   108160.5051   26740.5515
# 2017        836250  108122.4996   142383.0718    75998.7426   37092.6934
# 2018        729855   86397.2997   183160.0366    29190.6945   35054.8856
# 2019        927960        94866   289642.5641         28980    33126.464
# 2020     1002627.5      99607.5    522743.873         68100   47498.0636
# 2021  1697849.9743  151490.3962   351102.2981         81540    56703.673
#
#      RBREW_D_MCAP SIM_D_MCAP  TRYG_D_MCAP   VWS_D_MCAP
# date
# 2014   12064.0698    6743.75   41130.2096   50752.8762
# 2015   15543.4493      16102   39785.4808  108407.2473
# 2016   14747.6596    14284.3   36080.5111  101689.0281
# 2017     19593.86  14376.048   46893.3682   92405.0909
# 2018        22899    18046.8   49522.0557  101223.0031
# 2019        30561   30678.75   59674.2282  133900.8015
# 2020     34870.71   36672.75   58042.6291  290740.7842
# 2021   35975.3593    28949.4  105726.6197  201973.4008

# %%
esg.loc[:,['DBK_G_ESG','DBK_G_E','DBK_G_S','DBK_G_G']]
# Out:
#      DBK_G_ESG  DBK_G_E  DBK_G_S  DBK_G_G
# date
# 2014   35.9924   38.961  23.9117  45.0632
# 2015   42.2292   38.961  23.9117  63.7267
# 2016   42.5712   38.961  24.9395  63.7267
# 2017   48.8381   38.961   22.763  84.6478
# 2018   49.2808  40.2899   22.763  84.6478
# 2019   48.6269  40.2899  20.7981  84.6478
# 2020   48.6269  40.2899  20.7981  84.6478
# 2021   48.6269  40.2899  20.7981  84.6478

# %%
esg.loc[:,['DANSKE_D_ESG','DANSKE_D_E','DANSKE_D_S','DANSKE_D_G']]
# Out:
#      DANSKE_D_ESG DANSKE_D_E DANSKE_D_S DANSKE_D_G
# date
# 2014      42.4605    37.8436     21.705    67.7303
# 2015      40.6096    29.2057     21.705    70.8007
# 2016      40.4486    28.7224     21.705    70.8007
# 2017      42.6315    32.1051    24.8791    70.8007
# 2018      49.2506    26.2156    29.0206     92.354
# 2019      49.8642    33.7662    23.3071     92.354
# 2020      49.7234    33.3434    23.3071     92.354
# 2021      49.7234    33.3434    23.3071     92.354

# %%
tabl = []
for i in range (40):
    tabl.append(0+i)
tabl = pd.DataFrame(tabl)

# %%
tabl['2013_low'] = pd.DataFrame(thirteen_low)
tabl['2013_mid'] = pd.DataFrame(thirteen_mid)
tabl['2013_high'] = pd.DataFrame(thirteen_high)
tabl['2014_low'] = pd.DataFrame(thirteen_low)
tabl['2014_mid'] = pd.DataFrame(thirteen_mid)
tabl['2014_high'] = pd.DataFrame(thirteen_high)
tabl['2015_low'] = pd.DataFrame(fifteen_low)
tabl['2015_mid']= pd.DataFrame(fifteen_mid)
tabl['2015_high'] = pd.DataFrame(fifteen_high)
tabl['2016_low']= pd.DataFrame(sixteen_low)
tabl['2016_mid'] = pd.DataFrame(sixteen_mid)
tabl['2016_high'] = pd.DataFrame(sixteen_high)
tabl['2017_low'] = pd.DataFrame(seventeen_low)
tabl['2017_mid'] = pd.DataFrame(seventeen_mid)
tabl['2017_high'] = pd.DataFrame(seventeen_high)
tabl['2018_low'] = pd.DataFrame(eighteen_low)
tabl['2018_mid'] = pd.DataFrame(eighteen_mid)
tabl['2018_high'] = pd.DataFrame(eighteen_high)
tabl['2019_low'] = pd.DataFrame(nineteen_low)
tabl['2019_mid'] = pd.DataFrame(nineteen_mid)
tabl['2019_high'] = pd.DataFrame(nineteen_high)
tabl['2020_low'] = pd.DataFrame(twenty_low)
tabl['2020_mid'] = pd.DataFrame(twenty_mid)
tabl['2020_high'] = pd.DataFrame(twenty_high)
tabl['2021_low'] = pd.DataFrame(twentyone_low)
tabl['2021_mid'] = pd.DataFrame(twentyone_mid)
tabl['2021_high'] = pd.DataFrame(twentyone_high)
tabl['2022_low']  = pd.DataFrame(twentytwo_low)
tabl['2022_mid'] = pd.DataFrame(twentytwo_mid)
tabl['2022_high'] = pd.DataFrame(twentytwo_high)

# %%
#print(tabl.to_latex(index = True, multirow = True))

# %%
tabl.to_excel('tabl.xlsx')

# %%
tabl
# Out:
#      0 2013_low   2013_mid 2013_high 2014_low   2014_mid 2014_high 2015_low  \
# 0    0    BNR_G      DBK_G     ADS_G    BNR_G      DBK_G     ADS_G    BNR_G
# 1    1    CON_G      DPW_G     AIR_G    CON_G      DPW_G     AIR_G    FME_G
# 2    2    DTE_G     EOAN_G     ALV_G    DTE_G     EOAN_G     ALV_G    FRE_G
# 3    3    FME_G      HEI_G     BAS_G    FME_G      HEI_G     BAS_G   HNR1_G
# 4    4    FRE_G     HEN3_G    BAYN_G    FRE_G     HEN3_G    BAYN_G   PAH3_G
# 5    5   HNR1_G      MRK_G     BMW_G   HNR1_G      MRK_G     BMW_G    QIA_G
# 6    6   PAH3_G      RWE_G     DB1_G   PAH3_G      RWE_G     DB1_G   SRT3_G
# 7    7    PUM_G      SAP_G     IFX_G    PUM_G      SAP_G     IFX_G    ZAL_G
# 8    8    QIA_G      SY1_G     MBG_G    QIA_G      SY1_G     MBG_G    EVO_S
# 9    9   SRT3_G     VOW3_G     MTX_G   SRT3_G     VOW3_G     MTX_G  GETIB_S
# 10  10   ALIV_S    ASSAB_S    MUV2_G   ALIV_S    ASSAB_S    MUV2_G  HEXAB_S
# 11  11  GETIB_S    HEXAB_S     SIE_G  GETIB_S    HEXAB_S     SIE_G  INVEB_S
# 12  12  INVEB_S      HMB_S     ABB_S  INVEB_S      HMB_S     ABB_S  KINVB_S
# 13  13  KINVB_S     SHBA_S    ALFA_S  KINVB_S     SHBA_S    ALFA_S   SKAB_S
# 14  14  TEL2B_S     SKAB_S   ATCOA_S  TEL2B_S     SKAB_S   ATCOA_S   AKER_N
# 15  15   AKER_N     SKFB_S   ATCOB_S   AKER_N     SKFB_S   ATCOB_S  AKRBP_N
# 16  16  AKRBP_N    VOLVB_S     AZN_S  AKRBP_N    VOLVB_S     AZN_S  BAKKA_N
# 17  17  BAKKA_N      DNB_N     BOL_S  BAKKA_N      DNB_N     BOL_S  BWLPG_N
# 18  18    BWO_N      GJF_N   ELUXB_S    BWO_N      GJF_N   ELUXB_S    BWO_N
# 19  19    DNO_N      ORK_N   ERICB_S    DNO_N      ORK_N   ERICB_S    DNO_N
# 20  20    FRO_N      TGS_N     NDA_S    FRO_N      TGS_N     NDA_S  ENTRA_N
# 21  21    LSG_N  MAERSKA_D    SAND_S    LSG_N  MAERSKA_D    SAND_S    FRO_N
# 22  22   MOWI_N  MAERSKB_D    SCAB_S   MOWI_N  MAERSKB_D    SCAB_S    GJF_N
# 23  23   SALM_N     BAVA_D    SEBA_S   SALM_N     BAVA_D    SEBA_S    LSG_N
# 24  24   SCHA_N      CHR_D   SWEDA_S   SCHA_N      CHR_D   SWEDA_S   MOWI_N
# 25  25   SUBC_N    COLOB_D    SWMA_S   SUBC_N    COLOB_D    SWMA_S   SALM_N
# 26  26    TOM_N   DANSKE_D   TELIA_S    TOM_N   DANSKE_D   TELIA_S    TOM_N
# 27  27    STB_N   DEMANT_D    EQNR_N    STB_N   DEMANT_D    EQNR_N    STB_N
# 28  28  AMBUB_D      DSV_D     NHY_N  AMBUB_D      DSV_D     NHY_N  AMBUB_D
# 29  29   GMAB_D      FLS_D     TEL_N   GMAB_D      FLS_D     TEL_N    DSV_D
# 30  30     GN_D    NOVOB_D     YAR_N     GN_D    NOVOB_D     YAR_N   GMAB_D
# 31  31    LUN_D   PNDORA_D   CARLB_D    LUN_D   PNDORA_D   CARLB_D     GN_D
# 32  32  RBREW_D    ROCKB_D   NZYMB_D  RBREW_D    ROCKB_D   NZYMB_D    LUN_D
# 33  33    SIM_D     TRYG_D     VWS_D    SIM_D     TRYG_D     VWS_D  RBREW_D
# 34  34      NaN        NaN       NaN      NaN        NaN       NaN    SIM_D
# 35  35      NaN        NaN       NaN      NaN        NaN       NaN   TRYG_D
# 36  36      NaN        NaN       NaN      NaN        NaN       NaN      NaN
# 37  37      NaN        NaN       NaN      NaN        NaN       NaN      NaN
# 38  38      NaN        NaN       NaN      NaN        NaN       NaN      NaN
# 39  39      NaN        NaN       NaN      NaN        NaN       NaN      NaN
#
#      2015_mid 2015_high  2016_low   2016_mid 2016_high  2017_low   2017_mid  \
# 0       AIR_G     ADS_G     BNR_G      ADS_G     ALV_G     FME_G      ADS_G
# 1       CON_G     ALV_G     FME_G      AIR_G     BAS_G     FRE_G      AIR_G
# 2       DBK_G     BAS_G     FRE_G      DBK_G    BAYN_G    PAH3_G      BNR_G
# 3       DTE_G    BAYN_G    HNR1_G      DTE_G     BMW_G     PUM_G      DBK_G
# 4       HEI_G     BMW_G    PAH3_G      HEI_G     CON_G     QIA_G      DTE_G
# 5      HEN3_G     DB1_G     QIA_G     MUV2_G     DB1_G     EVO_S     HEN3_G
# 6      MUV2_G     DPW_G     VNA_G      PUM_G     DPW_G   GETIB_S     HNR1_G
# 7       PUM_G    EOAN_G     ZAL_G     SRT3_G    EOAN_G   HEXAB_S     MUV2_G
# 8       RWE_G     IFX_G     EVO_S     ALIV_S    HEN3_G     HMB_S      SAP_G
# 9       SAP_G     MBG_G   GETIB_S    ASSAB_S     IFX_G   INVEB_S      SIE_G
# 10      VNA_G     MRK_G   HEXAB_S    ATCOA_S     MBG_G   KINVB_S     SRT3_G
# 11     ALIV_S     MTX_G   INVEB_S    ATCOB_S     MRK_G    AKER_N      VNA_G
# 12    ATCOA_S     SIE_G   KINVB_S      HMB_S     MTX_G   BAKKA_N      ZAL_G
# 13    ATCOB_S     SY1_G    AKER_N      NDA_S     RWE_G   BWLPG_N     ALFA_S
# 14      HMB_S    VOW3_G   AKRBP_N     SHBA_S     SAP_G     BWO_N    ATCOA_S
# 15      NDA_S     ABB_S   BAKKA_N     SKAB_S     SIE_G     DNB_N    ATCOB_S
# 16     SHBA_S    ALFA_S   BWLPG_N    SWEDA_S     SY1_G     DNO_N      NDA_S
# 17    TEL2B_S   ASSAB_S     BWO_N     SWMA_S    VOW3_G   ENTRA_N     SEBA_S
# 18    VOLVB_S     AZN_S     DNB_N    TEL2B_S     ABB_S     FRO_N     SHBA_S
# 19      DNB_N     BOL_S     DNO_N    TELIA_S    ALFA_S     GJF_N     SKAB_S
# 20     SCHA_N   ELUXB_S   ENTRA_N    VOLVB_S     AZN_S     LSG_N    SWEDA_S
# 21     SUBC_N   ERICB_S     FRO_N      GJF_N     BOL_S    MOWI_N     SWMA_S
# 22      TEL_N    SAND_S     LSG_N     SCHA_N   ELUXB_S    SALM_N    TEL2B_S
# 23      TGS_N    SCAB_S    MOWI_N      TEL_N   ERICB_S    SUBC_N    TELIA_S
# 24  MAERSKA_D    SEBA_S    SALM_N      TGS_N    SAND_S     TOM_N    VOLVB_S
# 25  MAERSKB_D    SKFB_S    SUBC_N  MAERSKA_D    SCAB_S     STB_N    AKRBP_N
# 26     BAVA_D   SWEDA_S     TOM_N  MAERSKB_D    SEBA_S   AMBUB_D     SCHA_N
# 27      CHR_D    SWMA_S     STB_N     BAVA_D    SKFB_S  DANSKE_D      TEL_N
# 28    COLOB_D   TELIA_S   AMBUB_D      CHR_D    EQNR_N  DEMANT_D      TGS_N
# 29   DANSKE_D    EQNR_N  DEMANT_D    COLOB_D     NHY_N     DSV_D  MAERSKA_D
# 30   DEMANT_D     NHY_N     DSV_D   DANSKE_D     ORK_N    GMAB_D  MAERSKB_D
# 31      FLS_D     ORK_N    GMAB_D      FLS_D     YAR_N      GN_D     BAVA_D
# 32      ISS_D     YAR_N      GN_D      ISS_D   CARLB_D  PNDORA_D      CHR_D
# 33    NOVOB_D   CARLB_D  PNDORA_D      LUN_D   NZYMB_D   ROCKB_D    COLOB_D
# 34   PNDORA_D   NZYMB_D     SIM_D    NOVOB_D  ORSTED_D   RBREW_D      FLS_D
# 35    ROCKB_D     VWS_D    TRYG_D    ROCKB_D     VWS_D     SIM_D      ISS_D
# 36        NaN       NaN       NaN    RBREW_D       NaN    TRYG_D      LUN_D
# 37        NaN       NaN       NaN        NaN       NaN       NaN        NaN
# 38        NaN       NaN       NaN        NaN       NaN       NaN        NaN
# 39        NaN       NaN       NaN        NaN       NaN       NaN        NaN
#
#     2017_high  2018_low   2018_mid  2018_high  2019_low  2019_mid  2019_high  \
# 0       ALV_G     BNR_G      ADS_G      ALV_G     BNR_G     ADS_G      ALV_G
# 1       BAS_G     FME_G      AIR_G      BAS_G     FME_G     AIR_G      BAS_G
# 2      BAYN_G     FRE_G      CON_G     BAYN_G     FRE_G     CON_G     BAYN_G
# 3       BMW_G    PAH3_G      DBK_G      BMW_G    HNR1_G     DBK_G      BMW_G
# 4       CON_G     PUM_G      DTE_G      DB1_G    PAH3_G     DPW_G      DB1_G
# 5       DB1_G     QIA_G      HEI_G      DPW_G     PUM_G     DTE_G     EOAN_G
# 6       DPW_G    SRT3_G     HNR1_G     EOAN_G     QIA_G     HEI_G     HEN3_G
# 7      EOAN_G     EVO_S      SAP_G     HEN3_G    SRT3_G     SAP_G      IFX_G
# 8       HEI_G   HEXAB_S      SIE_G      IFX_G     EVO_S     VNA_G      MBG_G
# 9       IFX_G     HMB_S      VNA_G      MBG_G   HEXAB_S     ZAL_G      MRK_G
# 10      MBG_G   INVEB_S      ZAL_G      MRK_G   INVEB_S    ALFA_S      MTX_G
# 11      MRK_G   KINVB_S     ALFA_S      MTX_G   KINVB_S   ASSAB_S     MUV2_G
# 12      MTX_G    SKAB_S    ATCOA_S     MUV2_G     NDA_S   ATCOA_S      RWE_G
# 13      RWE_G    AKER_N    ATCOB_S      RWE_G    SWMA_S   ATCOB_S      SIE_G
# 14      SY1_G   BWLPG_N    GETIB_S      SY1_G    AKER_N   ELUXB_S      SY1_G
# 15     VOW3_G     BWO_N      NDA_S     VOW3_G   BWLPG_N   GETIB_S     VOW3_G
# 16      ABB_S     DNB_N     SEBA_S      ABB_S     BWO_N     HMB_S      ABB_S
# 17     ALIV_S     DNO_N     SHBA_S     ALIV_S     DNB_N    SEBA_S     ALIV_S
# 18    ASSAB_S   ENTRA_N    SWEDA_S    ASSAB_S     DNO_N    SHBA_S      AZN_S
# 19      AZN_S     FRO_N     SWMA_S      AZN_S   ENTRA_N    SKAB_S      BOL_S
# 20      BOL_S     GJF_N    TEL2B_S      BOL_S     FRO_N   SWEDA_S    ERICB_S
# 21    ELUXB_S     LSG_N    TELIA_S    ELUXB_S     GJF_N   TEL2B_S  ESSITYB_S
# 22    ERICB_S    MOWI_N    AKRBP_N    ERICB_S     LSG_N   TELIA_S     SAND_S
# 23  ESSITYB_S    SALM_N    BAKKA_N  ESSITYB_S    MOWI_N   VOLVB_S     SCAB_S
# 24     SAND_S     TOM_N     SCHA_N     SAND_S    SALM_N   BAKKA_N     SKFB_S
# 25     SCAB_S     STB_N     SUBC_N     SCAB_S    SCHA_N    SUBC_N    AKRBP_N
# 26     SKFB_S   AMBUB_D      TEL_N     SKFB_S     TOM_N     TEL_N     EQNR_N
# 27     EQNR_N  DEMANT_D      TGS_N    VOLVB_S     STB_N     TGS_N      NHY_N
# 28      NHY_N     DSV_D  MAERSKA_D     EQNR_N   AMBUB_D    BAVA_D      ORK_N
# 29      ORK_N    GMAB_D  MAERSKB_D      NHY_N  DEMANT_D     CHR_D      YAR_N
# 30      YAR_N      GN_D     BAVA_D      ORK_N     DSV_D   COLOB_D  MAERSKA_D
# 31    CARLB_D     LUN_D      CHR_D      YAR_N    GMAB_D  DANSKE_D  MAERSKB_D
# 32    NOVOB_D  PNDORA_D    COLOB_D    CARLB_D      GN_D     FLS_D    CARLB_D
# 33    NZYMB_D   ROCKB_D   DANSKE_D    NZYMB_D  PNDORA_D     ISS_D    NZYMB_D
# 34   ORSTED_D   RBREW_D      FLS_D   ORSTED_D   ROCKB_D     LUN_D   ORSTED_D
# 35      VWS_D     SIM_D      ISS_D      VWS_D     SIM_D   NOVOB_D      VWS_D
# 36        NaN    TRYG_D    NOVOB_D        NaN    TRYG_D   RBREW_D        NaN
# 37        NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 38        NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 39        NaN       NaN        NaN        NaN       NaN       NaN        NaN
#
#     2020_low  2020_mid  2020_high  2021_low   2021_mid  2021_high  2022_low  \
# 0      BNR_G     ADS_G      ALV_G     BNR_G      ADS_G      AIR_G     BNR_G
# 1      FME_G     AIR_G      BAS_G     DB1_G      CON_G      ALV_G     DB1_G
# 2      FRE_G     CON_G     BAYN_G     FME_G      DBK_G      BAS_G     FME_G
# 3     HNR1_G     DB1_G      BMW_G     FRE_G      DPW_G     BAYN_G     FRE_G
# 4     PAH3_G     DBK_G     EOAN_G    HNR1_G      PUM_G      BMW_G    HNR1_G
# 5      QIA_G     DPW_G      HEI_G    PAH3_G      SAP_G      DTE_G    PAH3_G
# 6      EVO_S     DTE_G     HEN3_G     QIA_G     SRT3_G     EOAN_G     QIA_G
# 7    HEXAB_S     PUM_G      IFX_G     EVO_S      ZAL_G      HEI_G     EVO_S
# 8      HMB_S     SAP_G      MBG_G   HEXAB_S     ALFA_S     HEN3_G   HEXAB_S
# 9    INVEB_S    SRT3_G      MRK_G     HMB_S     ALIV_S      IFX_G     HMB_S
# 10   KINVB_S     ZAL_G      MTX_G   INVEB_S    ASSAB_S      MBG_G   INVEB_S
# 11     NDA_S    ALFA_S     MUV2_G   KINVB_S    ATCOA_S      MRK_G   KINVB_S
# 12    SHBA_S    ALIV_S      RWE_G     NDA_S    ATCOB_S      MTX_G     NDA_S
# 13    SKAB_S   ASSAB_S      SIE_G    SKAB_S    ELUXB_S     MUV2_G    SKAB_S
# 14    SWMA_S   ATCOA_S      SY1_G    SWMA_S    GETIB_S      RWE_G    SWMA_S
# 15   TEL2B_S   ATCOB_S      VNA_G   TEL2B_S     SEBA_S      SIE_G   TEL2B_S
# 16   TELIA_S   ELUXB_S     VOW3_G   TELIA_S     SHBA_S      SY1_G   TELIA_S
# 17    AKER_N   GETIB_S      ABB_S    AKER_N     SKFB_S      VNA_G    AKER_N
# 18   BWLPG_N    SEBA_S      AZN_S   BWLPG_N    SWEDA_S     VOW3_G   BWLPG_N
# 19     BWO_N    SKFB_S      BOL_S     BWO_N    VOLVB_S      ABB_S     BWO_N
# 20     DNB_N   SWEDA_S    ERICB_S     DNB_N    BAKKA_N      AZN_S     DNB_N
# 21     DNO_N   VOLVB_S  ESSITYB_S     DNO_N    ENTRA_N      BOL_S     DNO_N
# 22     FRO_N   BAKKA_N     SAND_S     FRO_N     SUBC_N    ERICB_S     FRO_N
# 23     GJF_N   ENTRA_N     SCAB_S     GJF_N      TEL_N  ESSITYB_S     GJF_N
# 24     LSG_N    SUBC_N    AKRBP_N     LSG_N      TGS_N     SAND_S     LSG_N
# 25    MOWI_N     TEL_N     EQNR_N    MOWI_N    AMBUB_D     SCAB_S    MOWI_N
# 26    SALM_N     TGS_N      NHY_N    SALM_N  MAERSKA_D    AKRBP_N    SALM_N
# 27    SCHA_N   AMBUB_D      ORK_N    SCHA_N  MAERSKB_D     EQNR_N    SCHA_N
# 28     TOM_N    BAVA_D      YAR_N     TOM_N     BAVA_D      NHY_N     TOM_N
# 29     STB_N     CHR_D  MAERSKA_D     STB_N      CHR_D      ORK_N     STB_N
# 30  DEMANT_D   COLOB_D  MAERSKB_D  DEMANT_D    COLOB_D      YAR_N  DEMANT_D
# 31     DSV_D  DANSKE_D    CARLB_D     DSV_D   DANSKE_D    CARLB_D     DSV_D
# 32    GMAB_D     FLS_D    NZYMB_D    GMAB_D      FLS_D    NZYMB_D    GMAB_D
# 33      GN_D     ISS_D   ORSTED_D      GN_D      ISS_D   ORSTED_D      GN_D
# 34   ROCKB_D     LUN_D   PNDORA_D   ROCKB_D      LUN_D   PNDORA_D   ROCKB_D
# 35     SIM_D   NOVOB_D      VWS_D     SIM_D    NOVOB_D      VWS_D     SIM_D
# 36    TRYG_D   RBREW_D        NaN    TRYG_D    RBREW_D        NaN    TRYG_D
# 37       NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 38       NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 39       NaN       NaN        NaN       NaN        NaN        NaN       NaN
#
#      2022_mid  2022_high
# 0       ADS_G      AIR_G
# 1       CON_G      ALV_G
# 2       DBK_G      BAS_G
# 3       DPW_G     BAYN_G
# 4       PUM_G      BMW_G
# 5       SAP_G      DTE_G
# 6      SRT3_G     EOAN_G
# 7       ZAL_G      HEI_G
# 8      ALFA_S     HEN3_G
# 9      ALIV_S      IFX_G
# 10    ASSAB_S      MBG_G
# 11    ATCOA_S      MRK_G
# 12    ATCOB_S      MTX_G
# 13    ELUXB_S     MUV2_G
# 14    GETIB_S      RWE_G
# 15     SEBA_S      SIE_G
# 16     SHBA_S      SY1_G
# 17     SKFB_S      VNA_G
# 18    SWEDA_S     VOW3_G
# 19    VOLVB_S      ABB_S
# 20    BAKKA_N      AZN_S
# 21    ENTRA_N      BOL_S
# 22     SUBC_N    ERICB_S
# 23      TEL_N  ESSITYB_S
# 24      TGS_N     SAND_S
# 25    AMBUB_D     SCAB_S
# 26  MAERSKA_D    AKRBP_N
# 27  MAERSKB_D     EQNR_N
# 28     BAVA_D      NHY_N
# 29      CHR_D      ORK_N
# 30    COLOB_D      YAR_N
# 31   DANSKE_D    CARLB_D
# 32      FLS_D    NZYMB_D
# 33      ISS_D   ORSTED_D
# 34      LUN_D   PNDORA_D
# 35    NOVOB_D      VWS_D
# 36    RBREW_D        NaN
# 37        NaN        NaN
# 38        NaN        NaN
# 39        NaN        NaN
